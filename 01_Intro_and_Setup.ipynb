# %% [markdown]
# ### What is conda?
#
# Conda is an open-source package and environment manager. It installs software packages and manages isolated environments on your machine, preventing dependency conflicts between projects.
#
# ### Why use conda?
#
# Without a tool like conda, managing software dependencies becomes complex. Different projects often require different versions of Python and incompatible libraries. Conda solves this by creating isolated environments where each project gets exactly what it needs. You can maintain one environment with Python 3.10 for a legacy project and another with Python 3.14 for new development—then switch between them seamlessly.
#
# ### Key capabilities
# - **Environment management** Conda creates isolated spaces on your machine where you can install different versions of software without conflicts. You can create, activate, delete, and switch between environments as needed for different projects.
# - **Package installation** Conda downloads and installs packages from conda channels, which are repositories that host package files. It handles all the complexity of downloading the correct files for your operating system and architecture.
# - **Dependency resolution** When you install a package, conda automatically identifies all required dependencies and ensures compatible versions are installed together. This prevents version conflicts and broken installations.
# - **Multi-language support** While commonly used for Python, conda can manage packages written in any language, including R, C/C++, Ruby, and others.
# - **Cross-platform support** Conda works consistently across Windows, macOS, and Linux, making it easier to share reproducible environments across different operating systems.
#
# ### Conda, Mamba, and Anaconda
#
# All these commands refer to the same environment management method, and an environment created under one can be activated and used with the other.

# %% [markdown]
# ### Conda initial setup
#
# - **[CARC's Conda guide](https://www.carc.usc.edu/user-guides/hpc-systems/software/conda.html)**
#
# Prerequisite:

# %%
# %%bash
#
# ls -l ~/.bashrc
# ls -l ~/.bash_profile

# %% [markdown]
# If any of the above fail, copy the initial files from the operating system's repository. It needs to be done only once.
#
# #### Note: Do **not** execute the two cells below and copy anything if you have the required files

# %%
cp -v /etc/skel/.bashrc ~/.bashrc

# %%
cp -v /etc/skel/.bash_profile ~/.bash_profile

# %% [markdown]
# **Actual conda setup**

# %%
module purge
module load conda
conda init bash

# %% [markdown]
# ### Create a conda environment to use in exercise later
#
# Open a new tab in jupyterlab and start a terminal. Then create conda environment

# %% [markdown]
# `conda create -y -n simple_plots`

# %% [markdown]
# Install python in the freshly created empty environment

# %% [markdown]
# `conda install -y -c conda-forge python=3.12`

# %% [markdown]
# #### Conda channels. What is a channel?
#
# A channel is a location where conda searches for packages. When you install a package, conda queries the configured channels to find, download, and install the package files into your environment.
#
# **Why channels matter**
# Channels solve the distribution problem for conda packages. Different organizations and communities maintain their own channels to host packages they’ve built, curated, or want to share. This allows you to access packages from multiple sources while conda handles the complexity of finding compatible versions and resolving dependencies.

# %% [markdown]
# ### Integration of conda environment and JupyterLab
#
# - **[CARC's Jupyter kernel guide](https://www.carc.usc.edu/user-guides/hpc-systems/software/jupyter-kernels.html)**
#
# To connect your conda environment with your JupyterLab, you need the `ipykernel` package installed in your conda environment
#
# In the terminal with your simple-plots environment, install **`ipykernel`**

# %% [markdown]
# `pip3 install ipykernel`

# %% [markdown]
# After the ipykernel installation is complete, add the simple-plots environment to your Jupyterlab kernels with the following command

# %% [markdown]
# `python3 -m ipykernel install --user --name simple-plots --display-name "Simple Plots"`

# %% [markdown]
# #### At this point, you are ready to start exercises
#
# To continue, please open the last notebook [02_Simple_Plots.ipynb](./02_Simple_Plots.ipynb)
